# %% [markdown]
# # Data Wrangling
# http://pandas.pydata.org/pandas-docs/stable/io.html
#
# This page is first stop to figure out how to load file based data including files coming from web url

# %%
ls
# Out:
# Capstone/                      filename.png
# DataWrangling-IO.ipynb         filename200dpi.png
# DataWrangling.ipynb            foo.csv
# Learning-Jupyter-Pandas.ipynb  foo.h5
# README.md                      foo.xlsx
# animation.mp4                  matplotlib-tutorials.ipynb
# codecs.md                      notebook-master/
# data_hacking-master/           pandas-cookbook/
# data_wrangling_json.zip        pycon-notes.md
# data_wrangling_xml.zip         pycon-pandas-tutorial/
# datasciencecoursera/           site/
# double_pendulum.mp4

# %%
df = pd.read_csv('foo.csv', index_col=0, parse_dates=True)
df
# Out:
#                    A          B          C         D
# 2000-01-01  2.010060   1.118314  -0.520876 -0.365773
# 2000-01-02  2.068785  -0.887894  -0.400447 -0.209815
# 2000-01-03  1.302711  -0.826466   0.332370  0.921762
# 2000-01-04  3.004271  -1.979276  -0.906932  0.950753
# 2000-01-05  3.188819  -2.222684  -0.653723  1.407842
# 2000-01-06  0.901021  -1.516257  -0.381610  2.076504
# 2000-01-07  1.061703  -1.576431  -0.542894  2.323528
# 2000-01-08  0.731499  -3.210766   0.161314  3.348393
# 2000-01-09  0.477661  -2.134964  -0.717987  4.951102
# 2000-01-10 -0.446670  -2.518742  -1.036590  3.853486
# 2000-01-11  0.116837  -4.232895   0.697524  2.364268
# 2000-01-12 -0.806480  -4.069654   1.955292  1.660851
# 2000-01-13  0.061355  -3.614789   3.587542  1.350880
# 2000-01-14  0.911533  -4.846539   6.569479  0.503792
# 2000-01-15  0.837396  -4.092574   5.308758 -0.371647
# 2000-01-16  0.845400  -4.370826   6.132092  2.735466
# 2000-01-17  0.307252  -5.017732   8.989071  1.068407
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2002-09-17', '2002-09-18', '2002-09-19', '2002-09-20',
#                '2002-09-21', '2002-09-22', '2002-09-23', '2002-09-24',
#                '2002-09-25', '2002-09-26'],
#               dtype='datetime64[ns]', length=1000, freq=None)

# %% [markdown]
# The data below was originally taken from this url
# http://pandas.pydata.org/pandas-docs/stable/io.html#specifying-date-columns
# columns: KORD,19990127, 19:00:00, 18:56:00, 0.8100

# %%
clipdf = pd.read_clipboard(header=None, sep=',')
clipdf
# Out:
#       0         1          2          3     4
# 0  KORD  19990127   19:00:00   18:56:00  0.81
# 1  KORD  19990127   20:00:00   19:56:00  0.01
# 2  KORD  19990127   21:00:00   20:56:00 -0.59
# 3  KORD  19990127   21:00:00   21:18:00 -0.99
# 4  KORD  19990127   22:00:00   21:56:00 -0.59
# 5  KORD  19990127   23:00:00   22:56:00 -0.59

# %%
clipdf.to_csv('tmp.csv',index=False, header=False)
#!ls -l

# %%
print(open('tmp.csv').read())
# Out:
# KORD,19990127, 19:00:00, 18:56:00,0.81
# KORD,19990127, 20:00:00, 19:56:00,0.01
# KORD,19990127, 21:00:00, 20:56:00,-0.59
# KORD,19990127, 21:00:00, 21:18:00,-0.99
# KORD,19990127, 22:00:00, 21:56:00,-0.59
# KORD,19990127, 23:00:00, 22:56:00,-0.59

# %%
df = pd.read_csv('tmp.csv', header=None, parse_dates=[[1, 2], [1, 3]])
df
# Out:
#                   1_2                 1_3     0     4
# 0 1999-01-27 19:00:00 1999-01-27 18:56:00  KORD  0.81
# 1 1999-01-27 20:00:00 1999-01-27 19:56:00  KORD  0.01
# 2 1999-01-27 21:00:00 1999-01-27 20:56:00  KORD -0.59
# 3 1999-01-27 21:00:00 1999-01-27 21:18:00  KORD -0.99
# 4 1999-01-27 22:00:00 1999-01-27 21:56:00  KORD -0.59
# 5 1999-01-27 23:00:00 1999-01-27 22:56:00  KORD -0.59

# %%
df = pd.read_csv('tmp.csv', header=None, parse_dates=[[1, 2], [1, 3]],keep_date_col=True)
df
# Out:
#                   1_2                 1_3     0         1          2  \
# 0 1999-01-27 19:00:00 1999-01-27 18:56:00  KORD  19990127   19:00:00
# 1 1999-01-27 20:00:00 1999-01-27 19:56:00  KORD  19990127   20:00:00
# 2 1999-01-27 21:00:00 1999-01-27 20:56:00  KORD  19990127   21:00:00
# 3 1999-01-27 21:00:00 1999-01-27 21:18:00  KORD  19990127   21:00:00
# 4 1999-01-27 22:00:00 1999-01-27 21:56:00  KORD  19990127   22:00:00
# 5 1999-01-27 23:00:00 1999-01-27 22:56:00  KORD  19990127   23:00:00
#
#            3     4
# 0   18:56:00  0.81
# 1   19:56:00  0.01
# 2   20:56:00 -0.59
# 3   21:18:00 -0.99
# 4   21:56:00 -0.59
# 5   22:56:00 -0.59
